# %% [markdown]
# # Import Libraries

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import random
import glob
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import cv2
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16 , ResNet50,MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# # Check duplicate images Using Imagehash library

# %%
import shutil
import imagehash
from PIL import Image
from tqdm import tqdm  # Progress bar

#Define the path
dataset_folder = "/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"
output_folder = "/kaggle/working/cleaned_dataset"

# Create output folder
os.makedirs(output_folder, exist_ok=True)

# Function to remove duplicates and save unique images
def remove_duplicates_and_save(image_folder, output_label_folder):
    hashes = {}  # Store image hashes
    os.makedirs(output_label_folder, exist_ok=True)  # Create label folder

    all_images = os.listdir(image_folder)  # Get all images in folder
    total_images = len(all_images)  # Count total images
    duplicate_count = 0  # Counter for duplicate images

    for img_name in tqdm(all_images, desc=f"Processing {os.path.basename(image_folder)}"):
        img_path = os.path.join(image_folder, img_name)
        output_img_path = os.path.join(output_label_folder, img_name)

        try:
            img = Image.open(img_path).convert("RGB")  # Ensure correct format
            img_hash = imagehash.phash(img)  # Compute perceptual hash

            if img_hash not in hashes:  # If unique image
                hashes[img_hash] = img_path
                shutil.copy(img_path, output_img_path)  # Copy unique image
            else:
                duplicate_count += 1  # Increment duplicate counter

        except Exception as e:
            print(f" Error processing {img_name}: {e}")

    unique_images = total_images - duplicate_count  # Calculate remaining images

    # Print stats for the folder
    print(f"\n Label: {os.path.basename(image_folder)}")
    print(f" Total images: {total_images}")
    print(f" Duplicates removed: {duplicate_count}")
    print(f"Unique images saved: {unique_images}\n")

# Process each label folder separately
for label in os.listdir(dataset_folder):
    label_path = os.path.join(dataset_folder, label)
    output_label_path = os.path.join(output_folder, label)

    if os.path.isdir(label_path):  # Ensure it's a folder
        remove_duplicates_and_save(label_path, output_label_path)

print("\n✅ Dataset cleaned and saved in:", output_folder)
# Out:
# Processing Cyst: 100%|██████████| 3709/3709 [00:59<00:00, 62.22it/s]
#  Label: Cyst
#  Total images: 3709
#  Duplicates removed: 2063
# Unique images saved: 1646
# Processing Tumor: 100%|██████████| 2283/2283 [00:36<00:00, 61.78it/s]
#  Label: Tumor
#  Total images: 2283
#  Duplicates removed: 1172
# Unique images saved: 1111
# Processing Stone: 100%|██████████| 1377/1377 [00:24<00:00, 55.93it/s]
#  Label: Stone
#  Total images: 1377
#  Duplicates removed: 678
# Unique images saved: 699
# Processing Normal: 100%|██████████| 5077/5077 [01:19<00:00, 63.71it/s]
#  Label: Normal
#  Total images: 5077
#  Duplicates removed: 2537
# Unique images saved: 2540
#
#
# ✅ Dataset cleaned and saved in: /kaggle/working/cleaned_dataset

# %%
pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Splite The data to Train ,Test and Validation

# %%
import splitfolders 

# Define the cleaned dataset path
cleaned_dataset_folder = "/kaggle/working/cleaned_dataset"
output_split_folder = "/kaggle/working/split_dataset"

# Split the dataset into train, val, and test (70% - 15% - 15%)
splitfolders.ratio(cleaned_dataset_folder, output=output_split_folder, seed=42, ratio=(0.7, 0.15, 0.15))

print("\n✅ Dataset successfully split into Training, Validation, and Test sets!")
# Out:
# Copying files: 5996 files [00:01, 4311.71 files/s]
# ✅ Dataset successfully split into Training, Validation, and Test sets!

# %%
data_dirs = {
    "Train": "/kaggle/working/split_dataset/train",  
}

# Calculate the number of images in each class within each part
for data_type, path in data_dirs.items():
    print(f"\n {data_type} Data:")
    for class_name in os.listdir(path):  
        class_path = os.path.join(path, class_name)
        if os.path.isdir(class_path):  
            num_images = len(os.listdir(class_path))  
            print(f"  {class_name}: {num_images} images")
# Out:
#  Train Data:
#   Stone: 489 images
#   Tumor: 777 images
#   Normal: 1778 images
#   Cyst: 1152 images

# %% [markdown]
# **Imbalanced Data**

# %% [markdown]
# #  Data Augmentation for Tumor and Stone Class

# %%
train_dir = "/kaggle/working/split_dataset/train"

# Augmentation للصور
augmenter = ImageDataGenerator(
    rotation_range=15,  
    width_shift_range=0.1,
    height_shift_range=0.1,  
    shear_range=0.1, 
    zoom_range=0.1,  
    brightness_range=[0.9, 1.1],  
    fill_mode='nearest'
)

# Determine the classes that we will provide
classes_to_augment = ["Stone", "Tumor"]
target_images_per_class = 1200  # The target number after the Augmentation

for class_name in classes_to_augment:
    class_path = os.path.join(train_dir, class_name)
    images = os.listdir(class_path)
    
    num_existing_images = len(images)
    num_needed = target_images_per_class - num_existing_images
    
    print(f" {class_name}: has {num_existing_images} Image, we need {num_needed} Additional image")

    i = 0
    while num_existing_images + i < target_images_per_class:
        img_path = os.path.join(class_path, images[i % num_existing_images])  
        image = Image.open(img_path)
        image = np.array(image)
        image = image.reshape((1,) + image.shape)  #Transforming the image to a form that fits the Augmentation
        
        save_prefix = f"{class_name}_aug_{i}"  
        for batch in augmenter.flow(image, batch_size=1, save_to_dir=class_path, save_prefix=save_prefix, save_format="png"):
            i += 1
            if num_existing_images + i >= target_images_per_class:
                break
    
    print(f" The new photos were added to {class_name}, The number of Images has become: {target_images_per_class}")
# Out:
#  Stone: has 489 Image, we need 711 Additional image
#  The new photos were added to Stone, The number of Images has become: 1200
#  Tumor: has 777 Image, we need 423 Additional image
#  The new photos were added to Tumor, The number of Images has become: 1200

# %% [markdown]
# ### Images after Augmentation

# %%
data_dirs = {
    "Train": "/kaggle/working/split_dataset/train",  
}

# Calculate the number of images in each class within each part After Augmentation

print("Data After Augmentation")
for data_type, path in data_dirs.items():
    print(f"\n {data_type} Data:")
    for class_name in os.listdir(path):  
        class_path = os.path.join(path, class_name)
        if os.path.isdir(class_path):  
            num_images = len(os.listdir(class_path))  
            print(f"  {class_name}: {num_images} images")
# Out:
# Data After Augmentation
#
#  Train Data:
#   Stone: 1183 images
#   Tumor: 1195 images
#   Normal: 1778 images
#   Cyst: 1152 images

# %%
def display_images(data_path,num_img):
    random=np.random.randint(0,4,num_img)
    plt.figure(figsize=(15,10))
    for i in range(len(random)):
        # Get the list of class directories  
        class_name = os.listdir(data_path)[random[i]]
        class_path = os.path.join(data_path,class_name)
        random_img = np.random.randint(0,1000)
        image = os.listdir(class_path)[random_img]
        image_path = os.path.join(class_path,image)
        
        # Load and display the image  
        image = Image.open(image_path)
    
        plt.subplot(5,4,i+1)
        plt.imshow(image)
        plt.title(class_name)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

train_dir = "/kaggle/working/split_dataset/train"
display_images(train_dir , 20)

# %% [markdown]
# # Building The model

# %% [markdown]
# ## Load and Prepare Images

# %%
train_dir = '/kaggle/working/split_dataset/train'
validation_dir = '/kaggle/working/split_dataset/val'
test_dir = '/kaggle/working/split_dataset/test'

train_datagen = ImageDataGenerator(rescale=1./255)

validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    )

val_generator= validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(256,256),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(256,256),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 5308 images belonging to 4 classes.
# Found 897 images belonging to 4 classes.
# Found 903 images belonging to 4 classes.

# %% [markdown]
# ## 1- ResNet50

# %%
resnet_base = ResNet50(weights='imagenet',include_top=False , input_shape=(256,256,3))

model_resnet=Sequential()
model_resnet.add(resnet_base)
model_resnet.add(Flatten())
model_resnet.add(Dense(256, activation='relu'))
model_resnet.add(Dropout(0.5))
model_resnet.add(Dense(4, activation='softmax'))

resnet_base.trainable=False

model_resnet.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

model_resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 8, 8, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 131072)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      33,554,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57,143,428 (217.98 MB)
#  Trainable params: 33,555,716 (128.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
model_resnet.fit(train_generator,epochs=15,validation_data=val_generator,verbose=1,callbacks=[EarlyStopping(patience=5)])
# Out:
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 54s 231ms/step - accuracy: 0.3390 - loss: 6.8288 - val_accuracy: 0.4415 - val_loss: 1.2235
# Epoch 2/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3811 - loss: 1.2147 - val_accuracy: 0.5318 - val_loss: 1.0192
# Epoch 3/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4274 - loss: 1.1473 - val_accuracy: 0.5017 - val_loss: 1.0356
# Epoch 4/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 29s 165ms/step - accuracy: 0.4465 - loss: 1.1088 - val_accuracy: 0.5886 - val_loss: 0.8602
# Epoch 5/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4563 - loss: 1.0807 - val_accuracy: 0.5496 - val_loss: 0.8688
# Epoch 6/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4296 - loss: 1.1175 - val_accuracy: 0.5507 - val_loss: 0.8352
# Epoch 7/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4334 - loss: 1.1119 - val_accuracy: 0.5708 - val_loss: 0.8093
# Epoch 8/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.4512 - loss: 1.0887 - val_accuracy: 0.5998 - val_loss: 0.7985
# Epoch 9/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.4581 - loss: 1.0736 - val_accuracy: 0.5396 - val_loss: 0.8794
# Epoch 10/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 163ms/step - accuracy: 0.4777 - loss: 1.0463 - val_accuracy: 0.6276 - val_loss: 0.7329
# Epoch 11/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.5013 - loss: 0.9925 - val_accuracy: 0.6165 - val_loss: 0.7403
# Epoch 12/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 160ms/step - accuracy: 0.5102 - loss: 0.9830 - val_accuracy: 0.1271 - val_loss: 1.4278
# Epoch 13/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step - accuracy: 0.3512 - loss: 1.2490 - val_accuracy: 0.3846 - val_loss: 1.1219
# Epoch 14/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 27s 158ms/step - accuracy: 0.3679 - loss: 1.2098 - val_accuracy: 0.3634 - val_loss: 1.1280
# Epoch 15/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 28s 161ms/step - accuracy: 0.4162 - loss: 1.1660 - val_accuracy: 0.5017 - val_loss: 1.0277

# %%
test_loss, test_accuracy = model_resnet.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.3290 - loss: 1.0677
# Test Accuracy: 50.00%

# %% [markdown]
# ### Evaluate Resnet50

# %%
# Assuming you are using a test generator
y_pred_probs = model_resnet.predict(test_generator)  # Get predicted probabilities
y_pred_classes = np.argmax(y_pred_probs, axis=1)  # Convert to class labels

# True labels
y_true = test_generator.classes
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Generate the classification report (includes precision, recall, F1-score)
report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print(report)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#         Cyst       0.00      0.00      0.00       248
#       Normal       0.76      0.89      0.82       381
#        Stone       0.21      0.87      0.34       106
#        Tumor       1.00      0.10      0.18       168
#
#     accuracy                           0.50       903
#    macro avg       0.49      0.46      0.34       903
# weighted avg       0.53      0.50      0.42       903
#
# Confusion Matrix:
# [[  0   3 245   0]
#  [  0 339  42   0]
#  [  0  14  92   0]
#  [  0  91  60  17]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class_names = ["Stone", "Normal", "Cyst", "Tumor"]
# Drawing the confusion matrix with the names of the categories
sns.heatmap(cm, annot=True, cmap='YlGnBu', fmt='g', xticklabels=class_names, yticklabels=class_names)

plt.title('Confusion Matrix', y=1.15, size=15)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Sensitivity (Recall) and Specificity Calculation
TP = np.diag(cm)  # True Positives
FP = cm.sum(axis=0) - TP  # False Positives
FN = cm.sum(axis=1) - TP  # False Negatives
TN = cm.sum() - (FP + FN + TP)  # True Negatives

sensitivity = TP / (TP + FN)  # Recall
specificity = TN / (TN + FP)

print("Sensitivity (Recall):", sensitivity)

print("____________________________________________")

print("Specificity:", specificity)

# Compute AUC (one-vs-rest for multi-class)
y_true_one_hot = np.eye(len(test_generator.class_indices))[y_true]  # Convert to one-hot encoding
auc_score = roc_auc_score(y_true_one_hot, y_pred_probs, multi_class="ovr")
print("AUC Score: ", auc_score)
print("____________________________________________")
# Compute DSC (Dice Similarity Coefficient) for each class
dice_scores = (2 * TP) / (2 * TP + FP + FN)
print("Dice Similarity Coefficient (DSC) for each class:  ", dice_scores)
print("____________________________________________")
# Average Dice Score
average_dsc = np.mean(dice_scores)
print("Average Dice Similarity Coefficient (DSC):  ", average_dsc)
# Out:
# Sensitivity (Recall): [0.         0.88976378 0.86792453 0.10119048]
# ____________________________________________
# Specificity: [1.         0.79310345 0.56461731 1.        ]
# AUC Score:  0.7761256519895064
# ____________________________________________
# Dice Similarity Coefficient (DSC) for each class:   [0.         0.81884058 0.33761468 0.18378378]
# ____________________________________________
# Average Dice Similarity Coefficient (DSC):   0.3350597605982528

# %%
from sklearn.metrics import roc_curve, auc

# Number of classes
num_classes = len(test_generator.class_indices)

# Convert true labels to one-hot encoding
y_true_one_hot = np.eye(num_classes)[y_true]

# Initialize the plot
plt.figure(figsize=(8, 6))


class_labels = ["Stone", "Normal", "Cyst", "Tumor"]
# Loop through each class to calculate and plot ROC curve
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_one_hot[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {class_labels[i]} (AUC = {roc_auc:.2f})')

# Plot the diagonal reference line
plt.plot([0, 1], [0, 1], 'k--', lw=2, label="Random Guess")

# Customize the plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ## VGG_16

# %%
# Load VGG16 without the upper layers (fully connected layers)
vgg_base = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

#Build the Model
model_vgg = Sequential()
model_vgg.add(vgg_base)
model_vgg.add(Flatten())
model_vgg.add(Dense(256, activation='relu'))
model_vgg.add(Dropout(0.5))
model_vgg.add(Dense(4, activation='softmax'))

# Freeze the base model layers to prevent them from being trained
vgg_base.trainable = False

model_vgg.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model_vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 8, 8, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,104,580 (88.14 MB)
#  Trainable params: 8,389,892 (32.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model_vgg.fit(train_generator,epochs=15,validation_data=val_generator,verbose=1,callbacks=[EarlyStopping(patience=5)])
# Out:
# Epoch 1/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 81s 349ms/step - accuracy: 0.6123 - loss: 2.2142 - val_accuracy: 0.9287 - val_loss: 0.2777
# Epoch 2/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 201ms/step - accuracy: 0.8801 - loss: 0.3157 - val_accuracy: 0.9420 - val_loss: 0.1859
# Epoch 3/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.9169 - loss: 0.2245 - val_accuracy: 0.9889 - val_loss: 0.0537
# Epoch 4/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9409 - loss: 0.1470 - val_accuracy: 0.9833 - val_loss: 0.0574
# Epoch 5/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 199ms/step - accuracy: 0.9333 - loss: 0.1506 - val_accuracy: 0.9833 - val_loss: 0.0406
# Epoch 6/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 201ms/step - accuracy: 0.9475 - loss: 0.1227 - val_accuracy: 0.9922 - val_loss: 0.0336
# Epoch 7/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 201ms/step - accuracy: 0.9562 - loss: 0.1091 - val_accuracy: 0.9989 - val_loss: 0.0279
# Epoch 8/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9420 - loss: 0.1472 - val_accuracy: 0.9643 - val_loss: 0.0823
# Epoch 9/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9233 - loss: 0.1804 - val_accuracy: 0.9955 - val_loss: 0.0176
# Epoch 10/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 35s 202ms/step - accuracy: 0.9490 - loss: 0.1172 - val_accuracy: 0.9889 - val_loss: 0.0370
# Epoch 11/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9501 - loss: 0.1177 - val_accuracy: 0.9944 - val_loss: 0.0165
# Epoch 12/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 199ms/step - accuracy: 0.9510 - loss: 0.1120 - val_accuracy: 0.9911 - val_loss: 0.0292
# Epoch 13/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9357 - loss: 0.1547 - val_accuracy: 0.9955 - val_loss: 0.0099
# Epoch 14/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9557 - loss: 0.0972 - val_accuracy: 0.9933 - val_loss: 0.0188
# Epoch 15/15
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 34s 201ms/step - accuracy: 0.9369 - loss: 0.1609 - val_accuracy: 0.9933 - val_loss: 0.0293

# %%
test_loss, test_accuracy = model_vgg.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.9967 - loss: 0.0209
# Test Accuracy: 99.00%

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Generate the classification report (includes precision, recall, F1-score)
report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print(report)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
class_names = ["Cyst", "Normal", "Stone", "Tumor"]
# Drawing the confusion matrix with the names of the categories
sns.heatmap(cm, annot=True, cmap='YlGnBu', fmt='g', xticklabels=class_names, yticklabels=class_names)

plt.title('Confusion Matrix', y=1.15, size=15)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#         Cyst       0.00      0.00      0.00       248
#       Normal       0.76      0.89      0.82       381
#        Stone       0.21      0.87      0.34       106
#        Tumor       1.00      0.10      0.18       168
#
#     accuracy                           0.50       903
#    macro avg       0.49      0.46      0.34       903
# weighted avg       0.53      0.50      0.42       903
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve, auc

# Number of classes
num_classes = len(test_generator.class_indices)

# Convert true labels to one-hot encoding
y_true_one_hot = np.eye(num_classes)[y_true]

# Initialize the plot
plt.figure(figsize=(8, 6))


class_labels = ["Cyst", "Normal", "Stone", "Tumor"]
# Loop through each class to calculate and plot ROC curve
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_one_hot[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {class_labels[i]} (AUC = {roc_auc:.2f})')

# Plot the diagonal reference line
plt.plot([0, 1], [0, 1], 'k--', lw=2, label="Random Guess")

# Customize the plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %%
# Sensitivity (Recall) and Specificity Calculation
TP = np.diag(cm)  # True Positives
FP = cm.sum(axis=0) - TP  # False Positives
FN = cm.sum(axis=1) - TP  # False Negatives
TN = cm.sum() - (FP + FN + TP)  # True Negatives

sensitivity = TP / (TP + FN)  # Recall
specificity = TN / (TN + FP)

print("Sensitivity (Recall):", sensitivity)

print("____________________________________________")

print("Specificity:", specificity)

# Compute AUC (one-vs-rest for multi-class)
y_true_one_hot = np.eye(len(test_generator.class_indices))[y_true]  # Convert to one-hot encoding
auc_score = roc_auc_score(y_true_one_hot, y_pred_probs, multi_class="ovr")
print("AUC Score: ", auc_score)
print("____________________________________________")
# Compute DSC (Dice Similarity Coefficient) for each class
dice_scores = (2 * TP) / (2 * TP + FP + FN)
print("Dice Similarity Coefficient (DSC) for each class:  ", dice_scores)
print("____________________________________________")
# Average Dice Score
average_dsc = np.mean(dice_scores)
print("Average Dice Similarity Coefficient (DSC):  ", average_dsc)
# Out:
# Sensitivity (Recall): [0.         0.88976378 0.86792453 0.10119048]
# ____________________________________________
# Specificity: [1.         0.79310345 0.56461731 1.        ]
# AUC Score:  0.7761256519895064
# ____________________________________________
# Dice Similarity Coefficient (DSC) for each class:   [0.         0.81884058 0.33761468 0.18378378]
# ____________________________________________
# Average Dice Similarity Coefficient (DSC):   0.3350597605982528

# %% [markdown]
# ## MobileNetv2

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output_layer = Dense(4, activation='softmax')(x)

model_mobNet = Model(inputs=base_model.input, outputs=output_layer)

model_mobNet.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

model_mobNet.summary()
# Out:
# <ipython-input-26-0619c6acde49>:7: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(256, 256, 3))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4             │ (None, 256, 256, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 128, 128, 32)   │            864 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 128, 128, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 128, 128, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 128, 128, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 128, 128, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 128, 128, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 128, 128, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 128, 128, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 128, 128, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 128, 128, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 128, 128, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 129, 129, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 64, 64, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 64, 64, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 64, 64, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 64, 64, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 64, 64, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 64, 64, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 64, 64, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 64, 64, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 64, 64, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 64, 64, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 64, 64, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 64, 64, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 64, 64, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 64, 64, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 64, 64, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 64, 64, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 64, 64, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 65, 65, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 32, 32, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 32, 32, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 32, 32, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 32, 32, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 32, 32, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 32, 32, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 32, 32, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 32, 32, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 32, 32, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 32, 32, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 32, 32, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 32, 32, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 32, 32, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 32, 32, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 32, 32, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 32, 32, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 32, 32, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 32, 32, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 32, 32, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 32, 32, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 32, 32, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 32, 32, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 32, 32, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 32, 32, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 32, 32, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 32, 32, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 33, 33, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 16, 16, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 16, 16, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 16, 16, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 16, 16, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 16, 16, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 16, 16, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 16, 16, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 16, 16, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 16, 16, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 16, 16, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 16, 16, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 16, 16, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 16, 16, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 16, 16, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 16, 16, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 16, 16, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 16, 16, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 16, 16, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 16, 16, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 16, 16, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 16, 16, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 16, 16, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 16, 16, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 16, 16, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 16, 16, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 16, 16, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 16, 16, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 16, 16, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 16, 16, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 16, 16, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 16, 16, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 16, 16, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 16, 16, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 16, 16, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 16, 16, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 16, 16, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 16, 16, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 16, 16, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 16, 16, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 16, 16, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 16, 16, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 16, 16, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 16, 16, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 16, 16, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 16, 16, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 16, 16, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 16, 16, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 16, 16, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 16, 16, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 16, 16, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 16, 16, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 16, 16, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 16, 16, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 16, 16, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 16, 16, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 16, 16, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 16, 16, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 16, 16, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 16, 16, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 16, 16, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 16, 16, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 17, 17, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 8, 8, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 8, 8, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 8, 8, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 8, 8, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 8, 8, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 8, 8, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 8, 8, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 8, 8, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 8, 8, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 8, 8, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 8, 8, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 8, 8, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 8, 8, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 8, 8, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 8, 8, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 8, 8, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 8, 8, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 8, 8, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 8, 8, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 8, 8, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 8, 8, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 8, 8, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 8, 8, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 8, 8, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 8, 8, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 8, 8, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 8, 8, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 8, 8, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 8, 8, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 8, 8, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 8, 8, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 8, 8, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 8, 8, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 8, 8, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 128)            │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 4)              │            516 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,468 (9.24 MB)
#  Trainable params: 164,484 (642.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model_mobNet.fit(train_generator,epochs=10,validation_data=val_generator,verbose=1,callbacks=[EarlyStopping(patience=2)])
# Out:
# Epoch 1/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 47s 216ms/step - accuracy: 0.4474 - loss: 1.2616 - val_accuracy: 0.7224 - val_loss: 0.8698
# Epoch 2/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.7372 - loss: 0.7303 - val_accuracy: 0.7893 - val_loss: 0.6563
# Epoch 3/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 25s 148ms/step - accuracy: 0.8078 - loss: 0.5544 - val_accuracy: 0.8328 - val_loss: 0.5348
# Epoch 4/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.8485 - loss: 0.4430 - val_accuracy: 0.8651 - val_loss: 0.4478
# Epoch 5/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 149ms/step - accuracy: 0.8656 - loss: 0.3997 - val_accuracy: 0.8874 - val_loss: 0.3873
# Epoch 6/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - accuracy: 0.8874 - loss: 0.3385 - val_accuracy: 0.9030 - val_loss: 0.3341
# Epoch 7/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 25s 147ms/step - accuracy: 0.9025 - loss: 0.2963 - val_accuracy: 0.9275 - val_loss: 0.2956
# Epoch 8/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 25s 146ms/step - accuracy: 0.9138 - loss: 0.2778 - val_accuracy: 0.9309 - val_loss: 0.2610
# Epoch 9/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 150ms/step - accuracy: 0.9227 - loss: 0.2400 - val_accuracy: 0.9342 - val_loss: 0.2348
# Epoch 10/10
# 166/166 ━━━━━━━━━━━━━━━━━━━━ 26s 152ms/step - accuracy: 0.9408 - loss: 0.2076 - val_accuracy: 0.9454 - val_loss: 0.2122

# %%
test_loss, test_accuracy = model_mobNet.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9738 - loss: 0.1813
# Test Accuracy: 95.54%

# %% [markdown]
# ### Evaluate MobileNet

# %%
y_pred_probs = model_mobNet.predict(test_generator)  # Get predicted probabilities
y_pred_classes = np.argmax(y_pred_probs, axis=1)  # Convert to class labels

# True labels
y_true = test_generator.classes
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Generate the classification report (includes precision, recall, F1-score)
report = classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys())
print(report)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
class_names = ["Cyst", "Normal", "Stone", "Tumor"]
# Drawing the confusion matrix with the names of the categories
sns.heatmap(cm, annot=True, cmap='YlGnBu', fmt='g', xticklabels=class_names, yticklabels=class_names)

plt.title('Confusion Matrix', y=1.15, size=15)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#         Cyst       0.93      0.98      0.95       248
#       Normal       0.97      0.98      0.97       381
#        Stone       0.95      0.88      0.91       106
#        Tumor       0.95      0.90      0.92       168
#
#     accuracy                           0.95       903
#    macro avg       0.95      0.93      0.94       903
# weighted avg       0.95      0.95      0.95       903

# %%
TP = np.diag(cm)  # True Positives
FP = cm.sum(axis=0) - TP  # False Positives
FN = cm.sum(axis=1) - TP  # False Negatives
TN = cm.sum() - (FP + FN + TP)  # True Negatives

sensitivity = TP / (TP + FN)  # Recall
specificity = TN / (TN + FP)

print("Sensitivity (Recall): ", sensitivity)
print("_________________________________________________")

print("Specificity: ", specificity)
print("_________________________________________________")
# Compute AUC (one-vs-rest for multi-class)
y_true_one_hot = np.eye(len(test_generator.class_indices))[y_true]  # Convert to one-hot encoding
auc_score = roc_auc_score(y_true_one_hot, y_pred_probs, multi_class="ovr")
print("AUC Score:", auc_score)
print("_________________________________________________")

# Compute DSC (Dice Similarity Coefficient) for each class
dice_scores = (2 * TP) / (2 * TP + FP + FN)
print("Dice Similarity Coefficient (DSC) for each class: ", dice_scores)
print("_________________________________________________")
# Average Dice Score
average_dsc = np.mean(dice_scores)
print("Average Dice Similarity Coefficient (DSC): ", average_dsc)
# Out:
# Sensitivity (Recall):  [0.97580645 0.9816273  0.87735849 0.89880952]
# _________________________________________________
# Specificity:  [0.9740458  0.97509579 0.99372647 0.98911565]
# _________________________________________________
# AUC Score: 0.9942076480198202
# _________________________________________________
# Dice Similarity Coefficient (DSC) for each class:  [0.95463511 0.97395833 0.91176471 0.9235474 ]
# _________________________________________________
# Average Dice Similarity Coefficient (DSC):  0.9409763870771424

# %%
from sklearn.metrics import roc_curve, auc

# Number of classes
num_classes = len(test_generator.class_indices)

# Convert true labels to one-hot encoding
y_true_one_hot = np.eye(num_classes)[y_true]

# Initialize the plot
plt.figure(figsize=(8, 6))


class_labels = ["Cyst", "Normal", "Stone", "Tumor"]
# Loop through each class to calculate and plot ROC curve
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_one_hot[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {class_labels[i]} (AUC = {roc_auc:.2f})')

# Plot the diagonal reference line
plt.plot([0, 1], [0, 1], 'k--', lw=2, label="Random Guess")

# Customize the plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Multi-Class ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %%
import requests
from PIL import Image
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from io import BytesIO

# Function to download and preprocess the image
def load_image_from_url(url, target_size=(256, 256)):  # Adjust size as per your model input
    response = requests.get(url)
    image = Image.open(BytesIO(response.content))

    # Convert to RGB (in case the image is grayscale)
    image = image.convert("RGB")

    # Resize to match the model's expected input
    image = image.resize(target_size)

    # Convert to numpy array and normalize
    image_array = np.array(image) / 255.0  # Normalize (Rescale)

    # Add batch dimension
    image_array = np.expand_dims(image_array, axis=0)

    return image_array, image

# %%
image_url = "https://prod-images-static.radiopaedia.org/images/24804/1af425ddaf16fa001b5d129ec2ecbb_big_gallery.jpeg"

# Load and preprocess the image
image_array, image = load_image_from_url(image_url)

# Make a prediction
predictions = model_mobNet.predict(image_array)
predicted_class = np.argmax(predictions)  # Get the predicted class index

# Class labels (update according to your dataset)
class_labels = ["Cyst","Normal","Stone", "Tumor"]
predicted_label = class_labels[predicted_class]

# Display the image with the prediction
plt.imshow(image)
plt.axis("off")
plt.title(f"Predicted: {predicted_label}")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
model_mobNet.save('/kaggle/working/mobileNet_model.keras')
